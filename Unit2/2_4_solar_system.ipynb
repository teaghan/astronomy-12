# %% [markdown]
# # 2.4: The Structure and Components of Our Solar System
#
# In this lesson, we will explore the fascinating structure and components of our solar system. This will include an examination of the formation of the solar system, the central role of the Sun, the various planets, and other smaller bodies that orbit within our celestial neighborhood. This topic ties in with our previous discussions on gravity, circular motion, Kepler's Laws, and Newton's Law of Universal Gravitation, providing a deeper understanding of how these principles govern the dynamics of our solar system.
#
# <div class="alert alert-block alert-success">
#   <h4>Video</h4>
#   <p>Watch <a href="https://www.youtube.com/watch?v=libKVRa01L8" target="_blank">this video</a> for an excellent overview of the structure and components of our solar system. The video describes the formation of the solar system, the characteristics of its planets, and other significant features such as the asteroid belt and the Kuiper Belt.</p>
# </div>
#
# ---
#
# ### Formation of the Solar System
#
# Imagine a vast cloud of gas and dust floating in space, a remnant of ancient stellar explosions. About 4.5 billion years ago, this seemingly unremarkable cloud began to collapse under its own gravity. This was the solar nebula, and its collapse initiated the birth of our solar system.
#
# #### The Role of Gravity and Circular Motion
# - **Gravity**: As the solar nebula collapsed, gravity pulled the gas and dust towards the center, creating a dense core that would become the Sun.
# - **Circular Motion**: Conservation of angular momentum caused the collapsing cloud to spin faster and flatten into a rotating disc. Within this disc, particles collided and stuck together, forming planetesimals. These planetesimals merged to become protoplanets, the building blocks of our planets.
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Remember that the conservation of angular momentum explains why the collapsing cloud spun faster and flattened into a disc.
# </div>
#
# As the center of the nebula grew denser and hotter, nuclear fusion began, igniting our Sun. The remaining material in the disc coalesced into the planets, moons, asteroids, and comets that make up our solar system today.
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/nebula.png" alt="Solar Nebula" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# ---
#
# ### The Sun: The Central Star
#
# At the heart of our solar system lies the Sun, a G-type main-sequence star that accounts for more than 99% of the solar system's total mass. It is the source of energy that sustains life on Earth and drives the climate and weather.
#
# #### Structure of the Sun
# - **Core**: The innermost part where nuclear fusion occurs, converting hydrogen into helium and releasing immense amounts of energy.
# - **Radiative Zone**: Energy from the core travels outward by radiation.
# - **Convective Zone**: Energy is transported to the surface by convection currents.
# - **Photosphere**: The visible surface of the Sun, emitting the light we see.
# - **Chromosphere**: A layer above the photosphere, visible during solar eclipses as a reddish glow.
# - **Corona**: The Sun's outer atmosphere, extending millions of kilometers into space and visible during total solar eclipses.
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/sun_layers.png" alt="Layers of the Sun" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# #### Composition
# - The Sun is primarily composed of hydrogen (about 74%) and helium (about 24%), with trace amounts of heavier elements. The nuclear fusion process in the core converts hydrogen into helium, releasing energy that radiates outward and eventually reaches Earth, sustaining life and driving our climate.
#
# The Sun's immense gravitational pull keeps the planets in their orbits, and its energy output creates the dynamic environment of the solar system.
#
# ---
#
# ### The Planets: Types and Characteristics
#
# The planets in our solar system are divided into two main categories: Terrestrial and Jovian, each with distinct characteristics and fascinating features.
#
# #### Terrestrial Planets
# - **Mercury, Venus, Earth, Mars**
#   - These planets, closest to the Sun, are primarily composed of rocky material.
#   - **Mercury**: The smallest and closest planet to the Sun, with extreme temperature variations between day and night due to its thin atmosphere.
#   - **Venus**: Known as Earth's "sister planet," Venus is shrouded in thick clouds of sulfuric acid and has the hottest surface temperatures in the solar system, caused by a runaway greenhouse effect.
#   - **Earth**: The only known planet with liquid water and life, Earth has a diverse climate and geological features that support a rich biosphere.
#   - **Mars**: Known as the Red Planet, Mars has surface features reminiscent of both Earth and the Moon, with the largest volcano and canyon in the solar system. Evidence suggests it had liquid water in the past, raising the possibility of ancient microbial life.
#
# <div class="alert alert-block alert-info">
# <b>Interesting Fact:</b> Mars' Olympus Mons is the tallest volcano in the solar system, standing nearly three times the height of Mount Everest.
# </div>
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/Mercury_surface.png" alt="Terrestrial Planets" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# #### Jovian Planets
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/Giant_Planets.png" alt="Jovian Planets" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# - **Jupiter, Saturn, Uranus, Neptune**
#   - These giant planets are composed mostly of hydrogen, helium, and other volatiles.
#   - **Jupiter**: The largest planet, Jupiter is famous for its Great Red Spot, a massive storm that has raged for centuries, and its numerous moons, including Ganymede, the largest moon in the solar system.
#   - **Saturn**: Known for its stunning ring system, Saturn is a gas giant with a composition similar to Jupiter. Its rings are made of ice and rock particles, creating a spectacular visual display.
#   - **Uranus**: An ice giant with a unique axial tilt that causes it to rotate on its side, leading to extreme seasonal variations. Uranus is also known for its faint ring system and many moons.
#   - **Neptune**: The farthest planet from the Sun, Neptune is characterized by its deep blue color, caused by methane in its atmosphere, and its supersonic winds.
#
# <div class="alert alert-block alert-info">
# <b>Interesting Fact:</b> Neptune's moon Triton is the only large moon in the solar system that orbits its planet in the opposite direction of the planet's rotation (a retrograde orbit).
# </div>
#
# > **Interesting Fact**: The rings of Saturn are made mostly of ice particles, with some rock and dust, and their origin is still a topic of scientific research. Some hypotheses suggest they could be remnants of a destroyed moon or material left over from the planet's formation.
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/Jupiter.png" alt="Jupiter" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# ---
#
# ### Dwarf Planets and Small Solar System Bodies
#
# Beyond the eight major planets, our solar system contains several dwarf planets and smaller celestial bodies that add to its complexity and diversity.
#
# #### Dwarf Planets
# - **Examples**: Pluto, Eris, Ceres, Haumea, Makemake.
# - **Definition**: Dwarf planets are celestial bodies that orbit the Sun and are spherical in shape but have not cleared their orbital path of other debris.
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/Pluto" alt="Dwarf Planets" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# **The Story of Pluto**
# Once considered the ninth planet, Pluto was reclassified as a dwarf planet in 2006 by the International Astronomical Union (IAU). This decision was based on the fact that Pluto shares its orbit with other objects in the Kuiper Belt, a region beyond Neptune filled with icy bodies.
#
# > **Did You Know?**
# > The reclassification of Pluto sparked widespread debate and interest in the definitions of planetary bodies, highlighting the evolving nature of scientific understanding.
#
# ---
#
# ### Asteroids and the Asteroid Belt
#
# Asteroids are rocky remnants from the early solar system, providing a glimpse into the conditions and materials present during its formation.
#
# #### Location and Composition
# - The asteroid belt, located between Mars and Jupiter, contains millions of rocky objects. These range in size from tiny dust particles to the dwarf planet Ceres, the largest object in the belt.
#
# #### Significant Asteroids
# - **Ceres**: The first asteroid discovered, Ceres is now classified as a dwarf planet. It has a diameter of about 940 kilometers and contains a significant amount of water ice.
# - **Vesta**: The second-largest object in the asteroid belt, Vesta has a differentiated structure with a core, mantle, and crust, similar to terrestrial planets.
# - **Pallas**: Another large asteroid with an irregular shape and a heavily cratered surface.
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/Eros_Asteroid.png" alt="Asteroid Belt" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# > **Interesting Fact:**
# > The combined mass
#
#  of all the asteroids in the asteroid belt is less than that of Earth's Moon.
#
# ---
#
# ### Comets and the Kuiper Belt
#
# Comets, often described as "dirty snowballs," are icy bodies that provide valuable clues about the outer regions of the solar system.
#
# #### Structure and Components of Comets
# - **Nucleus**: The solid core composed of ice, dust, and organic compounds.
# - **Coma**: A glowing cloud of gas and dust that forms around the nucleus when a comet approaches the Sun.
# - **Tails**: Comets typically have two tails—an ion tail made of charged particles and a dust tail made of small solid particles. These tails always point away from the Sun due to the solar wind.
#
# #### The Kuiper Belt
# - Located beyond Neptune, the Kuiper Belt is a vast region filled with icy bodies and dwarf planets, including Pluto. It is also the source of short-period comets, which have orbits that bring them into the inner solar system at regular intervals.
#
# #### Famous Comets
# - **Halley's Comet**: Perhaps the most famous comet, Halley's Comet is visible from Earth approximately every 76 years. It was last seen in 1986 and will return in 2061.
# - **Comet Hale-Bopp**: One of the brightest comets of the 20th century, Hale-Bopp was visible to the naked eye for 18 months in 1996-1997.
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/Comet.png" alt="Comet" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# > **Did You Know?**
# > Comet tails can extend for millions of kilometers and are visible due to the sunlight reflecting off the dust and ionized gases.
#
# ---
#
# ### Meteoroids, Meteors, and Meteorites
#
# These small bodies provide a link between space and Earth's surface, offering insights into the materials and processes that shape our solar system.
#
# #### Differences
# - **Meteoroids**: Small rocky or metallic bodies traveling through space.
# - **Meteors**: The streaks of light we see when meteoroids enter Earth's atmosphere and burn up, commonly known as "shooting stars."
# - **Meteorites**: Meteoroids that survive their passage through the atmosphere and reach Earth's surface.
#
# #### Impact Events
# - Throughout Earth's history, meteorite impacts have had significant effects. One of the most famous impact events is the Chicxulub impact, which is believed to have caused the mass extinction of the dinosaurs about 66 million years ago.
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/meteor.png" alt="Meteor" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# > **Interesting Fact:**
# > The largest meteorite found on Earth is the Hoba meteorite in Namibia, weighing about 60 tons.
#
# ---
#
# ### Moons of the Solar System
#
# Many planets have moons, each with unique characteristics and fascinating features.
#
# #### Notable Moons
# - **Earth's Moon**: Influences tides and has visible phases. It is the only celestial body other than Earth where humans have set foot.
# - **Ganymede (Jupiter)**: The largest moon in the solar system, even larger than the planet Mercury.
# - **Titan (Saturn)**: Known for its thick atmosphere and lakes of liquid methane and ethane, Titan is a prime candidate for studying prebiotic chemistry.
# - **Europa (Jupiter)**: Suspected to have a subsurface ocean beneath its icy crust, making it a key target in the search for extraterrestrial life.
# - **Enceladus (Saturn)**: Emits water-ice geysers from its surface, suggesting the presence of a subsurface ocean that could harbor microbial life.
#
# <div class="alert alert-block alert-info">
# <b>Interesting Fact:</b> Europa's icy surface is crisscrossed by cracks and ridges, and beneath it lies a global ocean that contains more water than all of Earth's oceans combined.
# </div>
#
# #### Moon Formation Theories
# - **Giant Impact Hypothesis**: The most widely accepted theory suggests that Earth's Moon formed from the debris of a collision between the early Earth and a Mars-sized body named Theia.
# - **Capture Theory**: Proposes that the Moon was a wandering body captured by Earth's gravity.
# - **Co-formation Theory**: Suggests that Earth and the Moon formed together as a double system from the primordial accretion disc of the solar nebula.
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/Jupiter_moons.png" alt="Moons" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# ---
#
# ### The Oort Cloud
#
# The Oort Cloud is a hypothesized spherical shell of icy bodies surrounding the solar system, far beyond the Kuiper Belt.
#
# #### Hypothetical Cloud of Icy Bodies
# - Extending up to 100,000 astronomical units (AU) from the Sun, the Oort Cloud is believed to be the source of long-period comets, which have orbits that take them far beyond the planets and into the distant reaches of the solar system.
#
# #### Its Role in the Solar System
# - The Oort Cloud marks the outer boundary of the Sun's gravitational influence and is considered the edge of the solar system. It serves as a reservoir of icy bodies that occasionally get nudged into the inner solar system, becoming visible comets.
#
# <img src="https://raw.githubusercontent.com/teaghan/astronomy-12/main/Unit2/figures/oort_cloud.png" alt="Oort Cloud" width="1000" style="display: block; margin-left: auto; margin-right: auto;">
#
# > **Interesting Fact:**
# > The existence of the Oort Cloud was first proposed by Dutch astronomer Jan Oort in 1950, and while it has not been directly observed, its presence is inferred from the behavior of long-period comets.
#
# ---
#
# ### Check Your Understanding
#
# Apply the concepts you learned in the previous lessons to the solar system!
#
# 1. **Kepler's First Law**: Given that Mars has an average orbital radius of approximately 227.9 million kilometers and follows an elliptical orbit with the Sun at one focus, calculate the semi-major axis of Mars's orbit if its perihelion (closest approach to the Sun) is 206.7 million kilometers.
# <br><br>
# 2. **Kepler's Second Law**: If Mars sweeps out an area of $2 \times 10^8$ square kilometers in 15 days, what area will it sweep out in 30 days?
# <br><br>
# 3. **Kepler's Third Law**: Calculate the orbital period of a planet that is 4 AU from the Sun.
# <br><br>
# 4. **Newton's Law of Universal Gravitation**: Calculate the gravitational force between the Earth (mass = $5.97 \times 10^{24}$ kg) and the Moon (mass = $7.35 \times 10^{22}$ kg), given the average distance between them is 384,400 km.
# <br><br>
# 5. **Circular Motion and Gravitational Force**: Calculate the orbital speed of the International Space Station (ISS) orbiting at an altitude of 400 km above Earth's surface.
# <br><br>
# 6. **Newton's Second Law**: A comet with a mass of $1.0 \times 10^{12}$ kg is subjected to a gravitational force of $3.0 \times 10^{10}$ N when it is near the Sun. Calculate its acceleration.
# <br><br>
# 7. **Escape Velocity**: Calculate the escape velocity from the surface of Mars (mass = $6.42 \times 10^{23}$ kg, radius = 3,390 km).
# <br><br>
# 8. **Orbital Period**: Calculate the orbital period of a satellite orbiting 1,000 km above the Earth's surface.
# <br><br>
# 9. **Gravitational Potential Energy**: Calculate the gravitational potential energy of a 1,000 kg satellite at an altitude of 500 km above the Earth's surface.
# <br><br>
# 10. **Period of Revolution**: Calculate the period of revolution for an object in a circular orbit around the Sun with a radius of 2 AU.
# <br><br>
# 11. **Orbital Speed of a Moon**: Calculate the orbital speed of Jupiter's moon, Io, which orbits Jupiter at an average distance of 421,700 km.
# <br><br>
# 12. **Gravitational Acceleration on a Planet**: Calculate the gravitational acceleration on the surface of Saturn (mass = $5.68 \times 10^{26}$ kg, radius = 58,232 km).
# <br><br>
# 13. **Newton's Second Law in Circular Motion**: A satellite of mass 500 kg is in a circular orbit around the Earth at an altitude of 300 km. Calculate the centripetal force acting on the satellite.
# <br><br>
# 14. **Orbital Mechanics**: Calculate the velocity of a comet in its elliptical orbit around the Sun when it is at a distance of 1 AU from the Sun, given that its perihelion distance is 0.5 AU and its aphelion distance is 5.5 AU.
# <br><br>
# 15. **Energy of an Orbiting Satellite**: Calculate the total mechanical energy of a 1,000 kg satellite orbiting Earth at an altitude of 1,000 km.
# <br><br>
# ---
#
# ### Resources
#
# - **Astronomy** by Andrew Fraknoi, David Morrison, and Sidney C. Wolff
# - **Foundations of Astrophysics** by Barbara Ryden and Bradley M. Peterson

# %% [markdown]
# Building Planets
